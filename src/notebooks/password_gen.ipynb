# %%
from backend.security import get_password_hash

print(f"パスワードとして保持しておく値: {get_password_hash('my_password')}")
# Out:
# パスワードとして保持しておく値: $2b$12$3V4M/Y.QKHOi8vklCFSub.gusWekOly37zrpgBh2Il.KkCKJUIE/K
